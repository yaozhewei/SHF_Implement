# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# Epoch 0:
# 	train error     = 0.164500
# 	test error      = 0.168000
# 	lambda          = 0.922745
# Epoch 1:
# 	train error     = 0.097875
# 	test error      = 0.106000
# 	lambda          = 0.851458
# Epoch 2:
# 	train error     = 0.070875
# 	test error      = 0.080667
# 	lambda          = 0.785678
# Epoch 3:
# 	train error     = 0.057375
# 	test error      = 0.070333
# 	lambda          = 0.724980
# Epoch 4:
# 	train error     = 0.046125
# 	test error      = 0.058333
# 	lambda          = 0.668972
# Epoch 5:
# 	train error     = 0.042125
# 	test error      = 0.057333
# 	lambda          = 0.623525
# Epoch 6:
# 	train error     = 0.038000
# 	test error      = 0.055333
# 	lambda          = 0.575355
# Epoch 7:
# 	train error     = 0.036625
# 	test error      = 0.052667
# 	lambda          = 0.552683
# Epoch 8:
# 	train error     = 0.031500
# 	test error      = 0.050000
# 	lambda          = 0.541685
# Epoch 9:
# 	train error     = 0.028500
# ...
