# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# Epoch 0:
# 	train error     = 0.181250
# 	test error      = 0.189333
# 	lambda          = 0.922745
# Epoch 1:
# 	train error     = 0.099375
# 	test error      = 0.105000
# 	lambda          = 0.851458
# Epoch 2:
# 	train error     = 0.074750
# 	test error      = 0.085667
# 	lambda          = 0.785678
# Epoch 3:
# 	train error     = 0.059875
# 	test error      = 0.073000
# 	lambda          = 0.724980
# Epoch 4:
# 	train error     = 0.050125
# 	test error      = 0.067667
# 	lambda          = 0.675729
# Epoch 5:
# 	train error     = 0.045875
# 	test error      = 0.065333
# 	lambda          = 0.642612
# Epoch 6:
# 	train error     = 0.039875
# 	test error      = 0.057333
# 	lambda          = 0.592966
# Epoch 7:
# 	train error     = 0.036375
# 	test error      = 0.053333
# 	lambda          = 0.575355
# Epoch 8:
# 	train error     = 0.031625
# 	test error      = 0.051333
# 	lambda          = 0.547157
# Epoch 9:
# 	train error     = 0.032500
# ...
