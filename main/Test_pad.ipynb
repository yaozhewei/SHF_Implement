# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# Epoch 0:
# 	train error     = 0.064625
# 	test error      = 0.074667
# 	lambda          = 0.932065
# Epoch 1:
# 	train error     = 0.042750
# 	test error      = 0.058667
# 	lambda          = 0.932065
# Epoch 2:
# 	train error     = 0.036125
# 	test error      = 0.051667
# 	lambda          = 0.932065
# Epoch 3:
# 	train error     = 0.027375
# 	test error      = 0.045000
# 	lambda          = 0.932065
# Epoch 4:
# 	train error     = 0.028500
# 	test error      = 0.049333
# 	lambda          = 0.932065
# Epoch 5:
# 	train error     = 0.021500
# 	test error      = 0.039333
# 	lambda          = 0.932065
# Epoch 6:
# 	train error     = 0.018375
# 	test error      = 0.037667
# 	lambda          = 0.932065
# Epoch 7:
# 	train error     = 0.018375
# 	test error      = 0.035667
# 	lambda          = 0.932065
# Epoch 8:
# 	train error     = 0.015625
# 	test error      = 0.035667
# 	lambda          = 0.932065
# Epoch 9:
# 	train error     = 0.014125
# ...

# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# Epoch 0:
# 	train error     = 0.087250
# 	test error      = 0.095333
# 	lambda          = 0.913517
# Epoch 1:
# 	train error     = 0.046750
# 	test error      = 0.066333
# 	lambda          = 0.913517
# Epoch 2:
# 	train error     = 0.045625
# 	test error      = 0.062000
# 	lambda          = 0.913517
# Epoch 3:
# 	train error     = 0.035750
# 	test error      = 0.054667
# 	lambda          = 0.913517
# Epoch 4:
# 	train error     = 0.031125
# 	test error      = 0.053000
# 	lambda          = 0.913517
# Epoch 5:
# 	train error     = 0.024000
# 	test error      = 0.038333
# 	lambda          = 0.913517
# Epoch 6:
# 	train error     = 0.021125
# 	test error      = 0.040333
# 	lambda          = 0.913517
# Epoch 7:
# 	train error     = 0.019750
# 	test error      = 0.042000
# 	lambda          = 0.913517
# Epoch 8:
# 	train error     = 0.017750
# 	test error      = 0.038000
# 	lambda          = 0.913517
# Epoch 9:
# 	train error     = 0.014500
# ...
