# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# (384010, 1)
# (384010, 1)
# Epoch 0:
# 	train error     = 0.0979
# 	test error      = 0.1070
# 	lambda          = 0.10837234
# 	CG-decay        = 0.500
# Epoch 1:
# 	train error     = 0.1235
# 	test error      = 0.1440
# 	lambda          = 0.11744564
# 	CG-decay        = 0.500
# Epoch 2:
# 	train error     = 0.0729
# 	test error      = 0.0973
# 	lambda          = 0.13793478
# 	CG-decay        = 0.500
# Epoch 3:
# 	train error     = 0.0519
# 	test error      = 0.0703
# 	lambda          = 0.16363472
# 	CG-decay        = 0.500
# Epoch 4:
# 	train error     = 0.0467
# 	test error      = 0.0677
# 	lambda          = 0.20827196
# 	CG-decay        = 0.500
# Epoch 5:
# 	train error     = 0.0289
# 	test error      = 0.0493
# 	lambda          = 0.29607312
# 	CG-decay        = 0.500
# Epoch 6:
# 	train error     = 0.0236
# 	test error      = 0.0433
# 	lambda          = 0.34424771
# 	CG-decay        = 0.500
# Epoch 7:
# 	train error     = 0.0203
# ...

# %%
run usps_class.py
# Out:
# Preparing data...
# Training...
# (384010, 1)
# (384010, 1)
# Epoch 0:
# 	train error     = 0.0719
# 	test error      = 0.0813
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 1:
# 	train error     = 0.0459
# 	test error      = 0.0610
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 2:
# 	train error     = 0.0365
# 	test error      = 0.0570
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 3:
# 	train error     = 0.0300
# 	test error      = 0.0490
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 4:
# 	train error     = 0.0239
# 	test error      = 0.0440
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 5:
# 	train error     = 0.0205
# 	test error      = 0.0433
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 6:
# 	train error     = 0.0182
# 	test error      = 0.0407
# 	lambda          = 0.91351725
# 	CG-decay        = 0.500
# Epoch 7:
# 	train error     = 0.0170
# ...
